# %% [markdown]
# <a href="https://colab.research.google.com/github/yethuag/spotify-analysis/blob/main/yta_Spotify_Tracks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args

    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)

    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
url = "https://raw.githubusercontent.com/yethuag/spotify-analysis/refs/heads/main/tracks.csv"
spotify = pd.read_csv(url);
display('spotify.head(10)')
# Out:
# spotify.head(10)
#    Unnamed: 0                track_id                               artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5           5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6           6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7           7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8           8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9           9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
#
#                                           album_name  \
# 0                                             Comedy
# ...

# %%
print(spotify.columns)
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
spotify.shape
# Out:
# (114000, 21)

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
spotify.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
spotify.isnull().any() #for further data cleaning
# Out:
# Unnamed: 0          False
# track_id            False
# artists              True
# album_name           True
# track_name           True
# popularity          False
# duration_ms         False
# explicit            False
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# time_signature      False
# track_genre         False
# dtype: bool

# %%
#create a new duration min col and convert to Minutes for better calculation
spotify['duration_min'] = spotify['duration_ms'] / 60000
display('spotify.head(10)')
# Out:
# spotify.head(10)
#    Unnamed: 0                track_id                               artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5           5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6           6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7           7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8           8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9           9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
#
#                                           album_name  \
# 0                                             Comedy
# ...

# %%
spotify['duration_min'] = pd.to_numeric(spotify['duration_min'], errors='coerce')

# %%
spotify[spotify['artists'].isnull()] #have to fix this n make it not NaN
# Out:
#        Unnamed: 0                track_id artists album_name track_name  \
# 65900       65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN
#
#        popularity  duration_ms  explicit  danceability  energy  ...  mode  \
# 65900           0            0     False         0.501   0.583  ...     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature  track_genre  duration_min
# 65900  138.391               4        k-pop           0.0
#
# [1 rows x 22 columns]

# %%
spotify = spotify.dropna(subset=['artists'])

# %%
spotify.shape
# Out:
# (113999, 22)

# %%
spotify.isnull().sum() # just to make sure this data set is perfect
# Out:
# Unnamed: 0          0
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# duration_min        0
# dtype: int64

# %%
spotify.isnull().any() #assuming not included NaN, data is cleaned now
# Out:
# Unnamed: 0          False
# track_id            False
# artists             False
# album_name          False
# track_name          False
# popularity          False
# duration_ms         False
# explicit            False
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# time_signature      False
# track_genre         False
# duration_min        False
# dtype: bool

# %%
spotify.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  113999.000000  113999.000000  1.139990e+05  113999.000000
# mean    56999.421925      33.238827  2.280312e+05       0.566801
# std     32909.243463      22.304959  1.072961e+05       0.173543
# min         0.000000       0.000000  8.586000e+03       0.000000
# 25%     28499.500000      17.000000  1.740660e+05       0.456000
# 50%     56999.000000      35.000000  2.129060e+05       0.580000
# 75%     85499.500000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  113999.000000  113999.000000  113999.000000  113999.000000
# mean        0.641383       5.309126      -8.258950       0.637558
# std         0.251530       3.559999       5.029357       0.480708
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
top_10_artist_tb = spotify['artists'].value_counts().head(10)
top_10_artist_tb
# Out:
# artists
# The Beatles        279
# George Jones       271
# Stevie Wonder      236
# Linkin Park        224
# Ella Fitzgerald    222
# Prateek Kuhad      217
# Feid               202
# Chuck Berry        190
# Håkan Hellström    183
# OneRepublic        181
# Name: count, dtype: int64

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre', 'duration_min'],
#       dtype='object')

# %%
top_10_longest_track_durations = spotify[['track_name','duration_min']].sort_values(by='duration_min',ascending=False).head(10)
top_10_longest_track_durations
# Out:
#                                           track_name  duration_min
# 73617                       Unity (Voyage Mix) Pt. 1     87.288250
# 10935         Crossing Wires 002 - Continuous DJ Mix     79.817100
# 10984         Crossing Wires 002 - Continuous DJ Mix     79.817100
# 24348          The Lab 03 - Continuous DJ Mix Part 1     78.838367
# 73840            Amnesia Ibiza Underground 10 DJ Mix     76.064950
# 13344     House of Om - Mark Farina - Continuous Mix     74.125333
# 13245                 Live In Tokyo - Continuous Mix     72.330433
# 13195                        Greenhouse Construction     72.245350
# 27926   NQ State of Mind, Vol. 1 - Continuous DJ Mix     70.770100
# 101390                            Ocean Waves Sounds     68.670967

# %%
genre_popularity = spotify.groupby('track_genre')['popularity'].mean().sort_values(ascending=False).head(10)
genre_popularity
# Out:
# track_genre
# pop-film     59.283000
# k-pop        56.952953
# chill        53.651000
# sad          52.379000
# grunge       49.594000
# indian       49.539000
# anime        48.772000
# emo          48.128000
# sertanejo    47.866000
# pop          47.576000
# Name: popularity, dtype: float64

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre', 'duration_min'],
#       dtype='object')

# %%
def length_category(mins):
    if mins < 2:
        return 'Short'
    elif mins < 4:
        return 'Medium'
    elif mins < 6:
        return 'Long'
    else:
        return 'Epic'

spotify['length_category'] = spotify['duration_min'].apply(length_category)

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre', 'duration_min', 'length_category'],
#       dtype='object')

# %%
spotify['length_category']
# Out:
# 0         Medium
# 1         Medium
# 2         Medium
# 3         Medium
# 4         Medium
#            ...
# 113995      Epic
# 113996      Epic
# 113997      Long
# 113998      Long
# 113999      Long
# Name: length_category, Length: 113999, dtype: object

# %%
num_samples = 5

short_tracks = spotify[spotify['length_category'] == 'Short'].sample(num_samples)
medium_tracks = spotify[spotify['length_category'] == 'Medium'].sample(num_samples)
long_tracks = spotify[spotify['length_category'] == 'Long'].sample(num_samples)
epic_tracks = spotify[spotify['length_category'] == 'Epic'].sample(num_samples)

# %%
playlist_dataframe = pd.concat([short_tracks, medium_tracks, long_tracks, epic_tracks])
playlist_dataframe[['track_name', 'artists', 'duration_min', 'length_category']]
# Out:
#                                        track_name  \
# 94708                        Would You Be My Baby
# 101577   Pure White Noise - Loopable with No Fade
# 18754                                 Lead Finger
# 34413                         Saiyaan - Lofi Flip
# 16744                          Canon in C, K.508A
# 9098                                    Tudo azul
# 105545                   Walk Around Lake Johnson
# 19368                          Every Little Thing
# 920         (I Just) Died In Your Arms - Acoustic
# 45543                                 Pirate Girl
# 50703                              Volverte a Ver
# 22127                                 Unprocessed
# 8540                    I Done Lost My Good Thang
# 108963     Histoire du tango: III. Nightclub 1960
# 62978                                       Hello
# 40173                  Tu És a Fogueira - Ao Vivo
# 46240                      I Will Have That Power
# 24316   When A Thought Becomes You - Original Mix
# ...

# %%
popular_tracks = spotify.sort_values(by='popularity', ascending=False)
display('popular_tracks')
# Out:
# popular_tracks
#        Unnamed: 0                track_id                  artists  \
# 20001       20001  3nqQXoyQOWXiESFLlDF1hG     Sam Smith;Kim Petras
# 81051       81051  3nqQXoyQOWXiESFLlDF1hG     Sam Smith;Kim Petras
# 51664       51664  2tTmW7RDtMQtBk7m2rYeSw         Bizarrap;Quevedo
# 88410       88410  5ww2BF9slyYgNOk37BlC4u            Manuel Turizo
# 30003       30003  4uUG5RXrOk84mYEfFvj3cK  David Guetta;Bebe Rexha
# ...           ...                     ...                      ...
# 64890       64890  7KvE6pHVijDMMWjJ0DypKJ                Mel Tormé
# 64889       64889  4Gc4RjGYE0jljmrYBnR7A0                Lou Rawls
# 64888       64888  1to8N5c31zyFz0c3AahJs7                Mel Tormé
# 64887       64887  7qSkQJ5yeqXdJZjvVBf45e                Mel Tormé
# 64885       64885  3fERkaogWUgD0bEcbqs40u              Donald Byrd
#
#                                   album_name  \
# 20001              Unholy (feat. Kim Petras)
# 81051              Unholy (feat. Kim Petras)
# ...

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre', 'duration_min', 'length_category'],
#       dtype='object')

# %%
spotify[['track_name','energy']].sort_values(by='energy',ascending=False).head(20)
# Out:
#                                                track_name  energy
# 58391                                 Impulso Biomecanico     1.0
# 101991                                           Zen Rain     1.0
# 101964                               Rain Sound: Outdoors     1.0
# 46578                               Bass Be Louder - Edit     1.0
# 101719                      Heavy Rain on a Metal Rooftop     1.0
# 101895                          Meeresrauschen ohne Musik     1.0
# 101929                                   Rain and Thunder     1.0
# 101924                                         Clear Rain     1.0
# 22947                                   Do Lacre ao Lucro     1.0
# 101946                                 A Big Old Downpour     1.0
# 78481           Da sprach der alte Häuptling der Indianer     1.0
# 101529                                  Calming Sea Waves     1.0
# 101524                              Mountain Streams Alps     1.0
# ...

# %%
def mood(row):
    if row['energy'] > 0.7 and row['valence'] > 0.6:
        return 'Hype'
    elif row['energy'] < 0.4 and row['acousticness'] > 0.5:
        return 'Chill'
    elif row['valence'] < 0.3:
        return 'Dark'
    elif row['danceability'] > 0.7:
        return 'Dancey'
    else:
        return 'Mixed'

spotify['mood'] = spotify.apply(mood, axis=1)

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre', 'duration_min', 'length_category', 'mood'],
#       dtype='object')

# %%
(
    spotify[['mood', 'energy', 'track_name']]
    .sort_values('energy', ascending=False)
    .head(20)
    .style
    .background_gradient(cmap='RdYlGn', subset=['energy'])
    .set_caption('Energy Tracks by Mood')
)
# Out:
# <style type="text/css">
# #T_7a011_row0_col1, #T_7a011_row1_col1, #T_7a011_row2_col1, #T_7a011_row3_col1, #T_7a011_row4_col1, #T_7a011_row5_col1, #T_7a011_row6_col1, #T_7a011_row7_col1, #T_7a011_row8_col1, #T_7a011_row9_col1, #T_7a011_row10_col1, #T_7a011_row11_col1, #T_7a011_row12_col1, #T_7a011_row13_col1, #T_7a011_row14_col1, #T_7a011_row15_col1, #T_7a011_row16_col1, #T_7a011_row17_col1, #T_7a011_row18_col1, #T_7a011_row19_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7a011" class="dataframe">
#   <caption>Energy Tracks by Mood</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a011_level0_col0" class="col_heading level0 col0" >mood</th>
#       <th id="T_7a011_level0_col1" class="col_heading level0 col1" >energy</th>
#       <th id="T_7a011_level0_col2" class="col_heading level0 col2" >track_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre', 'duration_min', 'length_category', 'mood'],
#       dtype='object')

# %%
from matplotlib.colors import LinearSegmentedColormap

# Get top 20 by energy
top_energy = (
    spotify[['mood', 'energy', 'track_name']]
    .sort_values('energy', ascending=False)
    .head(20)
    .reset_index(drop=True)
)

spotify_green = '#1DB954'

colors = [spotify_green, '#FFFF00']
cmap = LinearSegmentedColormap.from_list('spotify_cmap', colors)
norm = plt.Normalize(top_energy['energy'].min(), top_energy['energy'].max())

fig, ax = plt.subplots(figsize=(10, 8))
ax.axis('off')

table_data = [
    ["Mood", "Energy", "Track Name"]
] + top_energy.values.tolist()

table = ax.table(cellText=table_data, colLabels=None, cellLoc='left', loc='center')
for i in range(3):
    cell = table[0, i]
    cell.set_facecolor('black')
    cell.set_text_props(color='white', weight='bold')

for i in range(1, len(table_data)):
    energy_val = table_data[i][1]
    color = cmap(norm(energy_val))
    table[i, 1].set_facecolor(color)

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.5)

plt.title("Energy Tracks by Mood", fontsize=16)
plt.tight_layout()
plt.show()

# %%
spotify['mood'].value_counts()
# Out:
# mood
# Mixed     34743
# Dark      23985
# Hype      22804
# Chill     18010
# Dancey    14457
# Name: count, dtype: int64

# %%
mood_counts = spotify['mood'].value_counts()
total = mood_counts.sum()
print("\nTotal mood tracks:", total)
# Out:
# Total mood tracks: 113999

# %%
spotify.shape
# Out:
# (113999, 24)

# %%
#milliseconds to minutes
spotify['duration_min'] = spotify['duration_ms'] / 60000
plt.figure(figsize=(12, 6))

#Ai generated styling
spotify['duration_min'].hist(bins=70,
                            color='#1DB954',
                            edgecolor='black',
                            alpha=0.8)

plt.title('Track Durations on Spotify',
          fontsize=18,
          pad=20)
plt.xlabel('Duration', fontsize=12)
plt.ylabel('Number of Tracks', fontsize=12)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)


plt.grid(axis='y', alpha=0.3)


mean_dur = spotify['duration_min'].mean()
median_dur = spotify['duration_min'].median()
plt.axvline(mean_dur, color='red', linestyle='--', linewidth=1.5, label=f'Mean: {mean_dur:.1f} min')
plt.axvline(median_dur, color='blue', linestyle=':', linewidth=1.5, label=f'Median: {median_dur:.1f} min')


plt.legend(fontsize=10)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)


plt.tight_layout()
plt.show()


#After researching,
#Playlist Modification in  shorter tracks like 2 to 3 mins would be better for streaming

# %%
top_tracks = spotify.sort_values('popularity', ascending=False).head(20)

# Set up figure
plt.figure(figsize=(14, 8))
ax = plt.subplot()

colors = plt.cm.Greens(np.linspace(0.4, 1, len(top_tracks)))

# Create horizontal bar plot
bars = ax.barh(top_tracks['track_name'].str[:30] + "...",
              top_tracks['popularity'],
              color=colors,
              edgecolor='black',
              height=0.7)

# Add popularity values on bars
ax.bar_label(bars,
             fmt='%d',
             padding=5,
             fontsize=9,
             color='black')

# Customize appearance
ax.set_title('Top 20 Most Popular Tracks On Spotify',
             fontsize=16,
             pad=20,
             fontweight='bold')
ax.set_xlabel('Popularity',
              fontsize=12)
ax.set_ylabel('Track Name',
              fontsize=12)
ax.set_xlim(0, 100)

plt.text(0.95, 0.05, 'Spotify',
         transform=ax.transAxes,
         fontsize=40,
         color='lightgray',
         alpha=0.3,
         ha='right',
         va='bottom')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)


ax.invert_yaxis()

plt.tight_layout()
plt.show()
